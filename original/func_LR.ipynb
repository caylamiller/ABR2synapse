# %% [markdown]
# # 0. Imports & Functions

# %%
from sklearn.metrics import mean_squared_error, r2_score

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import KFold, GroupKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.distributed
import pandas as pd
import numpy as np
from ABRA_35 import interpolate_and_smooth, CNN, plot_wave, calculate_and_plot_wave, plot_waves_single_frequency, arfread, get_str, calculate_hearing_threshold, all_thresholds, peak_finding
import warnings
from sklearn.preprocessing import StandardScaler,MinMaxScaler
warnings.filterwarnings('ignore')
import os
import io
import re
from scipy.ndimage import gaussian_filter1d
from scipy.signal import find_peaks

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import GroupShuffleSplit
import os
import struct
import datetime
# from skfda import FDataGrid
# from skfda.preprocessing.dim_reduction import FPCA
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import numpy as np
import pandas as pd
import struct
import matplotlib.pyplot as plt
import torch
from scipy.ndimage import gaussian_filter1d
import torch.nn as nn
import splitfolders
from tensorflow.keras.models import load_model
from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path
import torch
from PIL import Image
from torchvision.transforms import ToTensor
import random
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')
# import pytorch libraries
# %matplotlib inline
import torch 
import torch.autograd as autograd 
import torch.nn as nn 
import torch.nn.functional as F
import torch.optim as optim
import numpy as np4
from sklearn.metrics import r2_score
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import KFold, cross_val_score

import skfda
from skfda.ml.regression import LinearRegression
from skfda.representation.basis import BSplineBasis, FourierBasis, FDataBasis
from skfda.representation import FDataGrid
from skfda.preprocessing.smoothing import BasisSmoother
# from skfda.regression.linear_model import LinearFunctionalRegressor is no longer available? :(
# Out:
# 2025-05-15 00:34:24.944 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.011
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/envs/fda-env/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-05-15 00:34:25.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.014 Session state does not function when running a script without `streamlit run`
# 2025-05-15 00:34:25.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-15 00:34:25.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
filter1 = 128
filter2 = 32
dropout1 = 0.5
dropout2 = 0.3
dropout_fc = 0.1

# Model initialization
peak_finding_model = CNN(filter1, filter2, dropout1, dropout2, dropout_fc)
model_loader = torch.load('./models/waveI_cnn.pth')
peak_finding_model.load_state_dict(model_loader)
peak_finding_model.eval()
# Out:
# CNN(
#   (conv1): Conv1d(1, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(128, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (fc1): Linear(in_features=1952, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (dropout_fc): Dropout(p=0.1, inplace=False)
#   (batch_norm1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def peak_finding(wave):
    # Prepare waveform
    waveform=interpolate_and_smooth(wave) # Added indexing per calculate and plot wave function
    # waveform_torch = torch.tensor(waveform, dtype=torch.float32).unsqueeze(0) archived ABRA
    waveform_torch = torch.tensor(waveform, dtype=torch.float32).unsqueeze(0).unsqueeze(0) #newer ABRA
    # print(waveform_torch)
    # Get prediction from model
    outputs = peak_finding_model(waveform_torch)
    prediction = int(round(outputs.detach().numpy()[0][0], 0))
    # prediction_test = int(round(outputs.detach().numpy()[0], 0))
    # print("Model output:", outputs, "Prediction true start:", prediction)

    # Apply Gaussian smoothing
    smoothed_waveform = gaussian_filter1d(waveform, sigma=1)

    # Find peaks and troughs
    n = 18
    t = 14
    # start_point = prediction - 9 archived ABRA
    start_point = prediction - 6 #newer ABRA
    smoothed_peaks, _ = find_peaks(smoothed_waveform[start_point:], distance=n)
    smoothed_troughs, _ = find_peaks(-smoothed_waveform, distance=t)
    sorted_indices = np.argsort(smoothed_waveform[smoothed_peaks+start_point])
    highest_smoothed_peaks = np.sort(smoothed_peaks[sorted_indices[-5:]] + start_point)
    relevant_troughs = np.array([])
    for p in range(len(highest_smoothed_peaks)):
        c = 0
        for t in smoothed_troughs:
            if t > highest_smoothed_peaks[p]:
                if p != 4:
                    try:
                        if t < highest_smoothed_peaks[p+1]:
                            relevant_troughs = np.append(relevant_troughs, int(t))
                            break
                    except IndexError:
                        pass
                else:
                    relevant_troughs = np.append(relevant_troughs, int(t))
                    break
    relevant_troughs = relevant_troughs.astype('i')
    return highest_smoothed_peaks, relevant_troughs

def extract_metadata(metadata_lines):
    # Dictionary to store extracted metadata
    metadata = {}
    
    for line in metadata_lines:
        # Extract SW FREQ
        freq_match = re.search(r'SW FREQ:\s*(\d+\.?\d*)', line)
        if freq_match:
            metadata['SW_FREQ'] = float(freq_match.group(1))
        
        # Extract LEVELS
        levels_match = re.search(r':LEVELS:\s*([^:]+)', line)
        if levels_match:
            # Split levels and convert to list of floats
            metadata['LEVELS'] = [float(level) for level in levels_match.group(1).split(';') if level]
    
    return metadata

def read_custom_tsv(file_path):
    # Read the entire file
    with open(file_path, 'r', encoding='ISO-8859-1') as f:
        content = f.read()
    
    # Split the content into metadata and data sections
    metadata_lines = []
    data_section = None
    
    # Find the ':DATA' marker
    data_start = content.find(':DATA')
    
    if data_start != -1:
        # Extract metadata (lines before ':DATA')
        metadata_lines = content[:data_start].split('\n')
        
        # Extract data section
        data_section = content[data_start:].split(':DATA')[1].strip()
    
    # Extract specific metadata
    metadata = extract_metadata(metadata_lines)
    
    # Read the data section directly
    try:
        # Use StringIO to create a file-like object from the data section
        raw_data = pd.read_csv(
            io.StringIO(data_section), 
            sep='\s+',  # Use whitespace as separator
            header=None
        )
        raw_data = raw_data.T
        # Add metadata columns to the DataFrame
        if 'SW_FREQ' in metadata:
            raw_data['Freq(kHz)'] = metadata['SW_FREQ']
            # raw_data['Freq(Hz)'] = raw_data['Freq(Hz)'].apply(lambda x: x*1000)
        
        if 'LEVELS' in metadata:
            # Repeat levels to match the number of rows
            levels_repeated = metadata['LEVELS'] * (len(raw_data) // len(metadata['LEVELS']) + 1)
            raw_data['Level(dB)'] = levels_repeated[:len(raw_data)]
        
        filtered_data = raw_data.apply(pd.to_numeric, errors='coerce').dropna()
        filtered_data.columns = filtered_data.columns.map(str)

        columns = ['Freq(kHz)'] + ['Level(dB)'] + [col for col in filtered_data.columns if col.isnumeric() == True]
        filtered_data = filtered_data[columns]
        return filtered_data
    
    except Exception as e:
        print(f"Error reading data: {e}")
        return None, metadata

# %%
def peaks_troughs_amp_final(df, freq, db, time_scale=10, multiply_y_factor=1.0, units='Microvolts'):
    db_column = 'Level(dB)'
    
    khz = df[(df['Freq(kHz)'] == freq) & (df[db_column] == db)]
    if not khz.empty:
        index = khz.index.values[0]
        final = df.loc[index, '0':].dropna()
        final = pd.to_numeric(final, errors='coerce').dropna()

        target = int(244 * (time_scale / 10))
        
        # Process the wave as in calculate_and_plot_wave
        y_values = interpolate_and_smooth(final, target)
        
        # Apply scaling factor
        y_values *= multiply_y_factor
        
        # Handle units conversion if needed
        if units == 'Nanovolts':
            y_values /= 1000
            
        # Generate normalized version for peak finding
        y_values_fpf = interpolate_and_smooth(y_values[:244])
        
        # Standardize and normalize for peak finding, exactly as in the original
        flattened_data = y_values_fpf.flatten().reshape(-1, 1)
        scaler = StandardScaler()
        standardized_data = scaler.fit_transform(flattened_data)
        min_max_scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_data = min_max_scaler.fit_transform(standardized_data).reshape(y_values_fpf.shape)
        y_values_fpf = interpolate_and_smooth(scaled_data[:244])
        
        # Find peaks using the normalized data
        highest_peaks, relevant_troughs = peak_finding(y_values_fpf)
        
        # Calculate amplitude on the processed but non-normalized data
        if highest_peaks.size > 0 and relevant_troughs.size > 0:
            # Following the same approach as in the display_metrics_table function
            first_peak_amplitude = y_values[highest_peaks[0]] - y_values[relevant_troughs[0]]
            return highest_peaks, y_values, first_peak_amplitude
    
    return None, None, None

# %%
def full_interpolation(df, freq, db, time_scale=10, multiply_y_factor=1.0, units='Microvolts'):
    
    khz = df[(df['Freq(kHz)'] == freq) & (df['Level(dB)'] == db)]
    # print(khz)
    if not khz.empty:
        index = khz.index.values[0]
        final = df.loc[index, '0':].dropna()
        final = pd.to_numeric(final, errors='coerce').dropna()

        target = int(244 * (time_scale / 10))
        
        # Process the wave as in calculate_and_plot_wave
        y_values = interpolate_and_smooth(final, target)

        # print(f"Interpolated y_values: {y_values[:5]}")
        # print(f"Any NaNs? {np.isnan(y_values).any()}")

        if final.empty:
            print(f"Warning: Empty waveform for {freq}kHz @ {db}dB")
            return np.full((1, 244), np.nan)
        
        # Apply scaling factor
        y_values *= multiply_y_factor
        
        # Handle units conversion if needed
        if units == 'Nanovolts':
            y_values /= 1000
            
        # Generate normalized version for peak finding
        y_values_fpf = interpolate_and_smooth(y_values[:244])
        
        # Standardize and normalize for peak finding, exactly as in the original
        flattened_data = y_values_fpf.flatten().reshape(-1, 1)
        scaler = StandardScaler()
        standardized_data = scaler.fit_transform(flattened_data)
        min_max_scaler = MinMaxScaler(feature_range=(0, 1))
        scaled_data = min_max_scaler.fit_transform(standardized_data).reshape(y_values_fpf.shape)
    
        return scaled_data

# %% [markdown]
# Latency detection model to parametrize functional model based on individual wave morphology

# %%
def latency_all_peaks(highest_peaks, y_values, time_scale):
    latencies = []
    num_peaks = highest_peaks.size
    if num_peaks > 0:  # Check if highest_peaks is not empty
        for n in range(num_peaks): # SHOULD be 5 but there are cases where there are less. Will handle in later loops
            lat = highest_peaks[n] * (time_scale / len(y_values)) # Based on ABRA logic
            latencies.append(lat)
        return latencies
    else:
        print("No peaks detected. Check input data")
        return None

# %% [markdown]
# # 1. Data Imports

# %%
# del int
time_scale = 18
amp_per_freq = {'Subject': [], 'Latencies' : [], 'Freq(kHz) (x1)': [], 'Level(dB) (x2)': [], 'Amplitude (x3)':[]}
start_path = '/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/abr_data/WPZ Electrophysiology'
for subject in os.listdir(start_path):
    # print("Subject:",subject)
    for fq in os.listdir(os.path.join(start_path,subject)):
        # print(fq)
        if fq.startswith('ABR') and fq.endswith('.tsv'):
            path = os.path.join(start_path,subject,fq)
            data_df = read_custom_tsv(path)
            # print(data_df)
            freqs = data_df['Freq(kHz)'].unique().tolist()
            levels = data_df['Level(dB)'].unique().tolist()
            for freq in freqs:
                for lvl in levels:
                    highest_peaks, y_values, amp = peaks_troughs_amp_final(df=data_df, freq=freq, db=lvl, time_scale=time_scale)
                    latencies = latency_all_peaks(highest_peaks, y_values, time_scale)
                    if len(latencies) < 5:
                        print(subject, freq , latencies)
                        continue
                    amp_per_freq['Subject'].append(subject)
                    amp_per_freq['Freq(kHz) (x1)'].append(freq)
                    amp_per_freq['Level(dB) (x2)'].append(lvl)
                    amp_per_freq['Amplitude (x3)'].append(amp)
                    amp_per_freq['Latencies'].append(latencies)
        else:
            pass


amp_df_full = pd.DataFrame(data=amp_per_freq)

raw_synapse_counts = pd.read_excel('/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/WPZ Ribbon and Synapse Counts.xlsx')
# raw_synapse_counts = raw_synapse_counts.mask(lambda x: x.isnull()).dropna() # old approach 
raw_synapse_counts = raw_synapse_counts.mask(lambda x: x.isna(),0)
raw_synapse_counts['Synapses to IHC (y1)'] = raw_synapse_counts.iloc[:,6]
raw_synapse_counts['vx (x4)'] = raw_synapse_counts['vx']
raw_synapse_counts.drop(columns=['vx'], inplace=True)
raw_synapse_counts.rename(columns={'Freq':'Freq(kHz) (x1)'}, inplace=True)
raw_synapse_counts.rename(columns={'Case':'Subject'}, inplace=True)
# Out:
# WPZ62 45.2 [np.float64(3.3211845102505695), np.float64(5.207289293849659), np.float64(7.585421412300684), np.float64(9.225512528473804)]

# %%
# raw_synapse_counts[raw_synapse_counts['Subject'] == 'WPZ157']
lens = [len(x) for x in amp_df_full['Latencies']]
np.unique(lens)
# Out:
# array([5])

# %%
# Version 1 - values per vx

paired = amp_df_full.join(raw_synapse_counts.set_index(['Subject', 'Freq(kHz) (x1)']), on=['Subject', 'Freq(kHz) (x1)'])
# slice = paired[paired['Subject']=='WPZ174'][['Subject', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)','Synapses to IHC (y1)', 'IHCs (y2)']]
final = paired[['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)','Synapses to IHC (y1)', 'IHCs']]
final_clean = final.dropna()

# adding in the strain feature
strains = pd.read_excel('/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/WPZ Mouse groups.xlsx')
final_clean_strained = final_clean.join(strains.set_index('ID#'), on='Subject')
final_clean_strained['Strain'] = final_clean_strained['Strain'].str.strip()
final_clean_strained = final_clean_strained.rename(columns={'Strain': 'Strain (x5)'})
final_clean_strained = final_clean_strained.dropna()
final_clean_strained = final_clean_strained[['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)', 'Strain (x5)', 'Synapses to IHC (y1)', 'Group']]

final_clean_strained_grouped = final_clean_strained.copy()
final_clean_strained_grouped['Group - dB'] = final_clean_strained_grouped['Group'].apply(lambda x: x.split(' ')[0] if x.split(' ')[0].endswith('dB') else 'Control')
final_clean_strained_grouped['Group - Time Elapsed'] = final_clean_strained_grouped['Group'].apply(lambda x: x.split(' ')[1] if x.split(' ')[1].endswith(('h', 'wks', 'w')) else x.split(' ')[0])
final_clean_strained_grouped.head()

final_clean_strained_grouped_pos = final_clean_strained_grouped.copy()
final_clean_strained_grouped_pos['Amplitude (x3)'] = final_clean_strained_grouped['Amplitude (x3)'].apply(lambda x: 0 if x < 0 else x)

final_clean_strained_grouped_pos_cleangroup = final_clean_strained_grouped_pos.copy()
final_clean_strained_grouped_pos_cleangroup['Group'] = final_clean_strained_grouped_pos_cleangroup['Group'].apply(lambda x: x.strip())

final_clean_strained_grouped_pos_cleangroup.head()
final_clean_strained_grouped_pos_cleangroup_vs = final_clean_strained_grouped_pos_cleangroup.copy()
final_clean_strained_grouped_pos_cleangroup_vs['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs['Group - dB']
# final_clean_strained_grouped_pos_cleangroup_vs['Group - Time Elapsed (x7)'] = final_clean_strained_grouped_pos_cleangroup_vs['Group - Time Elapsed']
final_clean_strained_grouped_pos_cleangroup_vs = final_clean_strained_grouped_pos_cleangroup_vs[['Subject','Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)',
       'vx (x4)', 'Strain (x5)','Group - dB (x6)', 'Group - Time Elapsed', 'Group','Synapses to IHC (y1)']]

def split_on_number(input_string):
    return re.findall(r"[A-Za-z]+|\d+", input_string)

hrs_week = 24*7

final_clean_strained_grouped_pos_cleangroup_vs_timed = final_clean_strained_grouped_pos_cleangroup_vs.copy()
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'].apply(lambda x: '0dB' if x == 'Control' else x)
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'].apply(split_on_number)
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'].apply(lambda x: x[0])
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - dB (x6)'].apply(lambda x: int(x.strip()))
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Split'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed'].apply(split_on_number)
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Magn.'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Split'].apply(lambda x: x[0])
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Magn.'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Magn.'].apply(lambda x: int(x.strip()))
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Unit'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Split'].apply(lambda x: x[1])
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Unit'] = final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Time Elapsed - Unit'].apply(lambda x: "wks" if x == 'w' else x)
final_clean_strained_grouped_pos_cleangroup_vs_timed['Group - Hours Elapsed (x7)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed.apply(lambda row: row['Group - Time Elapsed - Magn.']* hrs_week if row['Group - Time Elapsed - Unit'] == 'wks' else row['Group - Time Elapsed - Magn.'], axis = 1)

final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded = final_clean_strained_grouped_pos_cleangroup_vs_timed.copy()
final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Strain encoded (x5)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Strain (x5)'].apply(lambda x: 0 if x=='C57B6' else 1)
final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded.head()
# Out:
#   Subject                                          Latencies  Freq(kHz) (x1)  \
# 0  WPZ145  [3.0751708428246016, 5.371298405466971, 6.6013...            45.2
# 0  WPZ145  [3.0751708428246016, 5.371298405466971, 6.6013...            45.2
# 1  WPZ145  [3.0341685649202734, 4.018223234624146, 5.9863...            45.2
# 1  WPZ145  [3.0341685649202734, 4.018223234624146, 5.9863...            45.2
# 2  WPZ145  [2.296127562642369, 3.6492027334851938, 6.5193...            45.2
#
#    Level(dB) (x2)  Amplitude (x3) vx (x4) Strain (x5)  Group - dB (x6)  \
# 0            70.0        0.033579      v1       C57B6               98
# 0            70.0        0.033579      v2       C57B6               98
# 1            75.0        0.034262      v1       C57B6               98
# 1            75.0        0.034262      v2       C57B6               98
# 2            80.0        0.154224      v1       C57B6               98
#
#   Group - Time Elapsed           Group  Synapses to IHC (y1)  \
# 0                 8wks  98dB 8wks post              8.750000
# 0                 8wks  98dB 8wks post             10.888889
# 1                 8wks  98dB 8wks post              8.750000
# 1                 8wks  98dB 8wks post             10.888889
# 2                 8wks  98dB 8wks post              8.750000
#
#   Group - Time Elapsed - Split  Group - Time Elapsed - Magn.  \
# 0                     [8, wks]                             8
# 0                     [8, wks]                             8
# 1                     [8, wks]                             8
# 1                     [8, wks]                             8
# 2                     [8, wks]                             8
#
#   Group - Time Elapsed - Unit  Group - Hours Elapsed (x7)  Strain encoded (x5)
# 0                         wks                        1344                    0
# 0                         wks                        1344                    0
# 1                         wks                        1344                    0
# 1                         wks                        1344                    0
# 2                         wks                        1344                    0

# %%
# Version 2 - Averaged per Vx

paired2 = amp_df_full.join(raw_synapse_counts.set_index(['Subject', 'Freq(kHz) (x1)']), on=['Subject', 'Freq(kHz) (x1)'])
# lilslice = paired[paired['Subject']=='WPZ174'][['Subject', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)','Synapses to IHC (y1)', 'IHCs']]
final2 = paired2[['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)','Synapses to IHC (y1)', 'Synapses', 'IHCs']]
final_clean2 = final2.dropna()

# adding in the strain feature
strains = pd.read_excel('/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/WPZ Mouse groups.xlsx')
final_clean_strained2 = final_clean2.join(strains.set_index('ID#'), on='Subject')
final_clean_strained2['Strain'] = final_clean_strained2['Strain'].str.strip()
final_clean_strained2 = final_clean_strained2.rename(columns={'Strain': 'Strain (x5)'})
final_clean_strained2 = final_clean_strained2.dropna()
final_clean_strained2 = final_clean_strained2[['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)', 'vx (x4)', 'Strain (x5)', 'Synapses to IHC (y1)', 'Group', 'Synapses', 'IHCs']]
# np.unique(final_clean_strained2['Group'])

# final_clean_70 = final_clean[final_clean['Level(dB) (x2)'] >= 70.0]
# final_clean_strained_70 = final_clean_strained[final_clean_strained['Level(dB) (x2)'] >= 70.0]
# # np.unique(final_clean['Level(dB) (x2)']) max level is 80 db
# len(final_clean), len(final_clean_70) # 10000 less data points!!!

final_clean_strained_grouped2 = final_clean_strained2.copy()
final_clean_strained_grouped2['Group - dB'] = final_clean_strained_grouped2['Group'].apply(lambda x: x.split(' ')[0] if x.split(' ')[0].endswith('dB') else 'Control')
final_clean_strained_grouped2['Group - Time Elapsed'] = final_clean_strained_grouped2['Group'].apply(lambda x: x.split(' ')[1] if x.split(' ')[1].endswith(('h', 'wks', 'w')) else x.split(' ')[0])
final_clean_strained_grouped2.head()

final_clean_strained_grouped_pos2 = final_clean_strained_grouped2.copy()
final_clean_strained_grouped_pos2['Amplitude (x3)'] = final_clean_strained_grouped2['Amplitude (x3)'].apply(lambda x: 0 if x < 0 else x)

len(final_clean_strained_grouped_pos2[final_clean_strained_grouped_pos2['Amplitude (x3)'] < 0])

final_clean_strained_grouped_pos2['Amplitude (x3)'] = final_clean_strained_grouped2['Amplitude (x3)'].apply(lambda x: 0 if x < 0 else x)

# final_clean_strained_grouped_pos[(final_clean_strained_grouped_pos['Subject'] == 'WPZ66') & (final_clean_strained_grouped_pos['Amplitude (x3)'] ==0.055901451434921576)
final_clean_strained_grouped_pos_cleangroup2 = final_clean_strained_grouped_pos2.copy()
final_clean_strained_grouped_pos_cleangroup2['Group'] = final_clean_strained_grouped_pos_cleangroup2['Group'].apply(lambda x: x.strip())
np.unique(final_clean_strained_grouped_pos_cleangroup2['Group'])

final_clean_strained_grouped_pos_cleangroup2.head()
final_clean_strained_grouped_pos_cleangroup_vs2 = final_clean_strained_grouped_pos_cleangroup2.copy()
final_clean_strained_grouped_pos_cleangroup_vs2['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs2['Group - dB']
# final_clean_strained_grouped_pos_cleangroup_vs['Group - Time Elapsed (x7)'] = final_clean_strained_grouped_pos_cleangroup_vs['Group - Time Elapsed']
final_clean_strained_grouped_pos_cleangroup_vs2 = final_clean_strained_grouped_pos_cleangroup_vs2[['Subject',  'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)', 'Amplitude (x3)',
       'vx (x4)', 'Strain (x5)','Group - dB (x6)', 'Group - Time Elapsed', 'Group','Synapses to IHC (y1)', 'Synapses', 'IHCs']]

def split_on_number(input_string):
    return re.findall(r"[A-Za-z]+|\d+", input_string)

hrs_week = 24*7

final_clean_strained_grouped_pos_cleangroup_vs_timed2 = final_clean_strained_grouped_pos_cleangroup_vs2.copy()
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'].apply(lambda x: '0dB' if x == 'Control' else x)
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'].apply(split_on_number)
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'].apply(lambda x: x[0])
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - dB (x6)'].apply(lambda x: int(x.strip()))
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Split'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed'].apply(split_on_number)
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Magn.'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Split'].apply(lambda x: x[0])
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Magn.'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Magn.'].apply(lambda x: int(x.strip()))
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Unit'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Split'].apply(lambda x: x[1])
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Unit'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Time Elapsed - Unit'].apply(lambda x: "wks" if x == 'w' else x)
final_clean_strained_grouped_pos_cleangroup_vs_timed2['Group - Hours Elapsed (x7)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2.apply(lambda row: row['Group - Time Elapsed - Magn.']* hrs_week if row['Group - Time Elapsed - Unit'] == 'wks' else row['Group - Time Elapsed - Magn.'], axis = 1)
final_clean_strained_grouped_pos_cleangroup_vs_timed2

freqs = np.unique(final_clean_strained_grouped_pos_cleangroup_vs_timed2['Freq(kHz) (x1)'])
subs = np.unique(final_clean_strained_grouped_pos_cleangroup_vs_timed2['Subject'])
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx = final_clean_strained_grouped_pos_cleangroup_vs_timed2.copy()
for freq in freqs:
    for sub in subs:
        mask = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq) & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)] # global for updates
        if len(mask) > 0:

            mask1 = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq) & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub) & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['vx (x4)'] == 'v1')]
            mask2 = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq) & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub) & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['vx (x4)'] == 'v2')]

            if not mask1.empty and not mask2.empty:
                mask1 = mask1.reset_index().iloc[0,:]
                mask2 = mask2.reset_index().iloc[0,:]

                total_syns = float(mask1['Synapses'] + mask2['Synapses'])
                total_ihcs = float(mask1['IHCs'] + mask2['IHCs'])

                if total_ihcs != 0:
                    ratio = total_syns / total_ihcs

                # if total_ihcs == 0 or total_syns == 0:
                #     print(sub, freq, total_syns, total_ihcs)
                # if total_syns == 0.0 or total_ihcs == 0.0:
                #     print(sub, freq)
                mask_index = mask.index
                final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx.loc[mask_index,'Synapse to IHC Ratio per Freq (y2)'] = ratio

# %%
np.unique(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Strain (x5)'])
# Out:
# array(['C57B6', 'CBA/CaJ'], dtype=object)

# %%
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx.copy()
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Strain encoded (x5)'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Strain (x5)'].apply(lambda x: 0 if x=='C57B6' else 1)
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded.head()
# Out:
#   Subject                                          Latencies  Freq(kHz) (x1)  \
# 0  WPZ145  [3.0751708428246016, 5.371298405466971, 6.6013...            45.2
# 0  WPZ145  [3.0751708428246016, 5.371298405466971, 6.6013...            45.2
# 1  WPZ145  [3.0341685649202734, 4.018223234624146, 5.9863...            45.2
# 1  WPZ145  [3.0341685649202734, 4.018223234624146, 5.9863...            45.2
# 2  WPZ145  [2.296127562642369, 3.6492027334851938, 6.5193...            45.2
#
#    Level(dB) (x2)  Amplitude (x3) vx (x4) Strain (x5)  Group - dB (x6)  \
# 0            70.0        0.033579      v1       C57B6               98
# 0            70.0        0.033579      v2       C57B6               98
# 1            75.0        0.034262      v1       C57B6               98
# 1            75.0        0.034262      v2       C57B6               98
# 2            80.0        0.154224      v1       C57B6               98
#
#   Group - Time Elapsed           Group  Synapses to IHC (y1)  Synapses IHCs  \
# 0                 8wks  98dB 8wks post              8.750000      77.0  8.8
# 0                 8wks  98dB 8wks post             10.888889      98.0    9
# 1                 8wks  98dB 8wks post              8.750000      77.0  8.8
# 1                 8wks  98dB 8wks post             10.888889      98.0    9
# 2                 8wks  98dB 8wks post              8.750000      77.0  8.8
#
#   Group - Time Elapsed - Split  Group - Time Elapsed - Magn.  \
# 0                     [8, wks]                             8
# 0                     [8, wks]                             8
# 1                     [8, wks]                             8
# 1                     [8, wks]                             8
# 2                     [8, wks]                             8
#
#   Group - Time Elapsed - Unit  Group - Hours Elapsed (x7)  \
# 0                         wks                        1344
# 0                         wks                        1344
# 1                         wks                        1344
# 1                         wks                        1344
# 2                         wks                        1344
#
#    Synapse to IHC Ratio per Freq (y2)  Strain encoded (x5)
# 0                            9.831461                    0
# 0                            9.831461                    0
# 1                            9.831461                    0
# 1                            9.831461                    0
# 2                            9.831461                    0

# %% [markdown]
# # 2. Waves as Inputs (FLM) - no additional predictors

# %% [markdown]
# ## a) Extract data as waves from ABR

# %%
time_scale = 18
start_path = '/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/abr_data/WPZ Electrophysiology'
subject_ABRs = {}

for subject in os.listdir(start_path):
    for fq in os.listdir(os.path.join(start_path,subject)):
        if fq.startswith('ABR') and fq.endswith('.tsv'):
            match = re.search(r'-L-([\d.]+)\.tsv$', fq)
            if match:
                freq = float(match.group(1))
                # if freq == 6.0 or freq == 7.0:
                #     print(subject, freq)
                # freqs.add(freq)
                path = os.path.join(start_path,subject,fq)
                data_df = read_custom_tsv(path)
                if data_df['Freq(kHz)'].iloc[0] == freq:
                    subject_ABRs[(subject, freq)] = data_df
                else:
                    print(f"Skipping subject {subject}, frequency {freq} due to mismatch.")
# Out:
# Skipping subject WPZ144, frequency 45.2 due to mismatch.
# Skipping subject WPZ161, frequency 45.2 due to mismatch.
# Skipping subject WPZ156, frequency 45.2 due to mismatch.
# Skipping subject WPZ146, frequency 45.2 due to mismatch.
# Skipping subject WPZ178, frequency 11.3 due to mismatch.
# Skipping subject WPZ40, frequency 45.2 due to mismatch.
# Skipping subject WPZ98, frequency 45.2 due to mismatch.
# Skipping subject WPZ155, frequency 8.0 due to mismatch.

# %% [markdown]
# ## b) Transform using skfda.DataGrid

# %%
time_scale = 18
subjects = []
frequencies = []
levels = []
waves = []
ys = []
fails = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(subject_ABRs[(sub, freq)]['Level(dB)']):
        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        # if wave.size != 244:
        #     fails.append((sub, freq, lvl))
        # else:
        wave_input = skfda.FDataGrid(
            data_matrix=wave,
            grid_points=time_scale * np.arange(0, 244) / 244
        )
        y = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        if len(y) > 0:
            y = float(y.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        waves.append(wave_input)
        ys.append(y)

# %%
fail_subs = set()
for fail in fails:
    # print(fail[0])
    fail_subs.add(fail[1])
# fail_subs
len(fails)
# Out:
# 0

# %% [markdown]
# ## c) Create and fit data to new bases

# %% [markdown]
# Creating a new basis is key for a functional regression. It brings the various waveforms into lower dimensional space by isolating the signal and filtering out noise. Basis-spline or B-spline is particularly useful for ABR waveforms:
# - Piecewise function = can control amount of smoothing and coefficient weighting *locally* (great for analyzing distinct peaks/troughs)
#     - We should use 5 knots or "pieces", 1 knot for each wave.
# - Does not assume periodicity like Fourier basis, giving a more natural fit
# - Cubic spline is standard for waveform data to capture wave variability without overly smoothing
#     - zB: 5 knots and 3 degrees (cubic splining) -> 7 basis pieces (5 + 3 -1) AKA we are splitting each waveform into 7 independent blocks
#
# https://projecteuclid.org/journals/annals-of-statistics/volume-33/issue-6/Functional-linear-regression-analysis-for-longitudinal-data/10.1214/009053605000000660.full
#
#
# https://en.wikipedia.org/wiki/B-spline
#
#
# https://pmc.ncbi.nlm.nih.gov/articles/PMC5598560/.

# %% [markdown]
# $f(t) = c_1 \, \phi_1(t) + c_2 \, \phi_2(t) + c_3 \, \phi_3(t) + c_4 \, \phi_4(t) + c_5 \, \phi_5(t) + c_6 \, \phi_6(t) + c_7 \, \phi_7(t)$

# %%
# Update timepoints post discussion/research!!!!!

# wave_timepoints = []
# basis = BSplineBasis(domain_range=(0,244), knots=wave_timepoints, order=3)

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, 18, 244)
basis = BSplineBasis(n_basis=7, domain_range=(0,18))
smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(subject_ABRs[(sub, freq)]['Level(dB)']):
        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)
        
        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        # print(y_series)
        
        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            # print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

# %%
final_waves_df = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
final_waves_df_clean = final_waves_df.dropna().reset_index(drop=True)
final_waves_df_clean.info()
len(final_waves_df_clean)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Subject                             5952 non-null   object
#  1   Freq(kHz)                           5952 non-null   float64
#  2   Level(dB)                           5952 non-null   float64
#  3   Transformed Waves (X)               5952 non-null   object
#  4   Synapse to IHC Ratio per Freq (y2)  5952 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 232.6+ KB
# 5952

# %% [markdown]
# ## d) Initial Train-Test Split

# %%
X = final_waves_df_clean['Transformed Waves (X)']
X_new = np.vstack([x.flatten() for x in X])

y = final_waves_df_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
train_rmse, test_rmse = [], []

for train_idx, test_idx in kf.split(X=X_new,y=y,groups=final_waves_df_clean['Subject']):
    X_train, X_test = X_new[train_idx], X_new[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_train_hat = model.predict(X_train)
    y_test_hat = model.predict(X_test)

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

np.mean(train_rmse), np.mean(test_rmse)
# print(X_new)
# Out:
# (np.float64(2.8984591728881317), np.float64(2.9254893957115957))

# %% [markdown]
# Next Steps
# - Add regularization
# - Check why so many N/A
# - Fix the knots to fit to 5 waves
#     - If bad, experiment with different settings

# %% [markdown]
# # 3. Add Frequency as Predictor

# %%
X = final_waves_df_clean['Transformed Waves (X)']
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_clean['Freq(kHz)'])

y = final_waves_df_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
train_rmse, test_rmse = [], []

for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

np.mean(train_rmse), np.mean(test_rmse)
# Out:
# (np.float64(2.8610348719204337), np.float64(2.90442682264057))

# %% [markdown]
# # 4. Tuning # of knots. Individualize this based on the peaks detected by ABRA

# %% [markdown]
# Now that we have the waves segmented via latency, we can use this to parametrize knots per wave and hopefully improve our predictions!!!

# %% [markdown]
# ## a) Extract data as waves from ABR (filtering out where freq filename != freq in-file AND if N/A in synapse file)

# %%
time_scale = 18
start_path = '/Users/leahashebir/Downloads/Manor_Practicum/liberman_data/abr_data/WPZ Electrophysiology'
subject_ABRs = {}

for subject in os.listdir(start_path):
    if subject in raw_synapse_counts['Subject'].values: # excluding subjects not in synapse count file
        for fq in os.listdir(os.path.join(start_path,subject)):
            if fq.startswith('ABR') and fq.endswith('.tsv'):
                match = re.search(r'-L-([\d.]+)\.tsv$', fq)
                if match:
                    freq = float(match.group(1))
                    if freq in raw_synapse_counts[raw_synapse_counts['Subject'] == subject]['Freq(kHz) (x1)'].values:
                        # if freq == 6.0 or freq == 7.0:
                        #     print(subject, freq)
                        # freqs.add(freq)
                        path = os.path.join(start_path,subject,fq)
                        data_df = read_custom_tsv(path)
                        if data_df['Freq(kHz)'].iloc[0] == freq:
                            subject_ABRs[(subject, freq)] = data_df
                        else:
                            print(f"Skipping subject {subject}, frequency {freq} due to mismatch.")
# Out:
# Skipping subject WPZ144, frequency 45.2 due to mismatch.
# Skipping subject WPZ161, frequency 45.2 due to mismatch.
# Skipping subject WPZ156, frequency 45.2 due to mismatch.
# Skipping subject WPZ146, frequency 45.2 due to mismatch.
# Skipping subject WPZ178, frequency 11.3 due to mismatch.
# Skipping subject WPZ98, frequency 45.2 due to mismatch.
# Skipping subject WPZ155, frequency 8.0 due to mismatch.

# %% [markdown]
# ## b) Transform using skfda.DataGrid and set new basis!

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Strain (x5)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)
        
        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
        smoother = BasisSmoother(basis=basis, return_basis=True)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
final_waves_df_new_basis_clean = final_waves_df_new_basis.dropna().reset_index(drop=True)
# Out:
# N/A latencies: (WPZ145, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ145, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ142, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ174, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ180, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ173, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ118, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ116, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 32.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 32.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ129, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ172, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ175, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 16.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 16.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 32.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 32.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 22.6, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 22.6, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ143, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ144, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# ...
# N/A latencies: (WPZ137, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ137, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 32.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 16.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 16.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 22.6, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 22.6, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ130, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 22.6, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 32.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 11.3, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 11.3, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ139, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ106, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 8.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 22.6, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 35.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 45.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 55.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 65.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 75.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 45.2, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 11.3, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 16.0, 80.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 10.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 15.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 20.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 25.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 30.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 40.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 50.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 60.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 70.0) : Series([], Name: Latencies, dtype: object)
# N/A latencies: (WPZ101, 32.0, 80.0) : Series([], Name: Latencies, dtype: object)

# %% [markdown]
# ## c) TT-Split with only individualized basis waves

# %%
X = final_waves_df_new_basis_clean['Transformed Waves (X)']
X_relevant_waves = [x[1:] for x in X]
X_new = np.vstack([x.flatten() for x in X_relevant_waves])

y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
train_rmse, test_rmse = [], []

for train_idx, test_idx in kf.split(X=X_new,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    X_train, X_test = X_new[train_idx], X_new[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_train_hat = model.predict(X_train)
    y_test_hat = model.predict(X_test)

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

np.mean(train_rmse), np.mean(test_rmse)
# print(X_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 X = final_waves_df_new_basis_clean['Transformed Waves (X)']
#       2 X_relevant_waves = [x[1:] for x in X]
# ----> 3 X_new = np.vstack([x.flatten() for x in X_relevant_waves])
#       5 y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']
#       7 kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
#
# File /opt/anaconda3/envs/fda-env/lib/python3.11/site-packages/numpy/_core/shape_base.py:287, in vstack(tup, dtype, casting)
#     285 if not isinstance(arrs, tuple):
#     286     arrs = (arrs,)
# --> 287 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# ## d) Parametrized waves + frequency

# %%
X = final_waves_df_new_basis_clean['Transformed Waves (X)']
X_relevant_waves = [x[:5] for x in X]
X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_clean['Freq(kHz)'])

y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
train_rmse, test_rmse = [], []

for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

np.mean(train_rmse), np.mean(test_rmse)
# Out:
# (np.float64(2.868142699267886), np.float64(2.899335287819347))

# %% [markdown]
# # 5. Finetuning Process (based on 4)

# %% [markdown]
# ## Finetuning on lambda

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

shared_grid = np.linspace(0, 18, 244)
penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
time_scale = 18

# tuning penalty_amount and smoother!!!!! Set up the for loop
for alpha in np.logspace(-4,2,10):
    subjects = []
    frequencies = []
    levels = []
    raw_waves = []
    newbasis_waves = []
    Xs = []
    ys = []
    fails = []

    for (sub, freq), df in subject_ABRs.items():
        for lvl in np.unique(df['Level(dB)']):
            latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                    & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
                ['Latencies']
            
            if len(latencies_series) == 0:
                print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
                continue

            latencies = latencies_series.values[0]
            latencies = [float(x) for x in latencies]
            # print(latencies)

            lvl = float(lvl)
            wave = full_interpolation(df, freq, lvl, time_scale)
            wave = np.asarray(wave, dtype=float)
            wave = wave.reshape(1, -1)
            
            grid = time_scale * np.arange(0, 244) / 244
            wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

            basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
            smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter=alpha)

            wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

            X = wave_newbasis.coefficients

            y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
                ['Synapse to IHC Ratio per Freq (y2)']
            
            # print(y_series)

            if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
                print(f'N/A y: ({sub}, {freq}, {lvl})')
                continue

            y = float(y_series.iloc[0])

            # print((sub, freq, lvl, y))
            subjects.append(sub)
            frequencies.append(freq)
            levels.append(lvl)
            raw_waves.append(wave_input)
            newbasis_waves.append(wave_newbasis)
            Xs.append(X.flatten()) # used for model fitting, same as for OLS!
            ys.append(y)
            
    final_waves_df_new_basis = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
    final_waves_df_new_basis_clean = final_waves_df_new_basis.dropna().reset_index(drop=True)

    # Start CV!!
    X = final_waves_df_new_basis_clean['Transformed Waves (X)']
    X_relevant_waves = [x for x in X]
    X_func = np.vstack([x.flatten() for x in X_relevant_waves])
    X_nonfunc = pd.DataFrame(final_waves_df_new_basis_clean[['Freq(kHz)', 'Level(dB)']])

    y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']

    kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    best_alpha = None
    best_score = np.inf

    train_rmse, test_rmse = [], []  

    # for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
        X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
        X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        scaler = StandardScaler()
        X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
        X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

        model = LinearRegression()
        model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

        y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
        y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

        train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
        test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

    avg_train_rmse = np.mean(train_rmse)
    avg_test_rmse = np.mean(test_rmse)

    if avg_test_rmse < best_score:
        best_score = avg_test_rmse
        best_alpha = alpha

print(f"Best alpha: {best_alpha:.4e} with RMSE {best_score:.4f}")
# Out:
# Best alpha: 1.0000e+02 with RMSE 2.8544

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

shared_grid = np.linspace(0, 18, 244)
penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
time_scale = 18

# tuning penalty_amount and smoother!!!!! Set up the for loop
for alpha in np.logspace(-4,2,10):
    subjects = []
    frequencies = []
    levels = []
    raw_waves = []
    newbasis_waves = []
    Xs = []
    ys = []
    fails = []

    for (sub, freq), df in subject_ABRs.items():
        for lvl in np.unique(df['Level(dB)']):
            latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                    & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
                ['Latencies']
            
            if len(latencies_series) == 0:
                print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
                continue

            latencies = latencies_series.values[0]
            latencies = [float(x) for x in latencies]
            # print(latencies)

            lvl = float(lvl)
            wave = full_interpolation(df, freq, lvl, time_scale)
            wave = np.asarray(wave, dtype=float)
            wave = wave.reshape(1, -1)
            
            grid = time_scale * np.arange(0, 244) / 244
            wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

            basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
            smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter=1.0000e+02)

            wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

            X = wave_newbasis.coefficients

            y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
                ['Synapse to IHC Ratio per Freq (y2)']
            
            # print(y_series)

            if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
                print(f'N/A y: ({sub}, {freq}, {lvl})')
                continue

            y = float(y_series.iloc[0])

            # print((sub, freq, lvl, y))
            subjects.append(sub)
            frequencies.append(freq)
            levels.append(lvl)
            raw_waves.append(wave_input)
            newbasis_waves.append(wave_newbasis)
            Xs.append(X.flatten()) # used for model fitting, same as for OLS!
            ys.append(y)
            
    final_waves_df_new_basis = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
    final_waves_df_new_basis_clean = final_waves_df_new_basis.dropna().reset_index(drop=True)

    # Start CV!!
    X = final_waves_df_new_basis_clean['Transformed Waves (X)']
    X_relevant_waves = [x for x in X]
    X_func = np.vstack([x.flatten() for x in X_relevant_waves])
    X_nonfunc = pd.DataFrame(final_waves_df_new_basis_clean[['Freq(kHz)', 'Level(dB)']])

    y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']

    kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    best_alpha = None
    best_score = np.inf

    train_rmse, test_rmse = [], []  

    # for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
        X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
        X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        scaler = StandardScaler()
        X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
        X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

        model = LinearRegression()
        model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

        y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
        y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

        train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
        test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

    avg_train_rmse = np.mean(train_rmse)
    avg_test_rmse = np.mean(test_rmse)

    if avg_test_rmse < best_score:
        best_score = avg_test_rmse
        best_alpha = alpha

print(f"Best alpha: {best_alpha:.4e} with RMSE {best_score:.4f}")
# Out:
# Best alpha: 1.0000e+02 with RMSE 2.8544

# %% [markdown]
# ## Extracting coefficients from our best model

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []
bases = []
all_latencies = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        all_latencies.append(latencies)
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)
        
        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
        bases.append(basis)
        smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter=1.0000e+02)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx['Level(dB) (x2)'] == lvl)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis_best = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Latencies' : all_latencies, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
final_waves_df_new_basis_best_clean = final_waves_df_new_basis_best.dropna().reset_index(drop=True)
final_waves_df_new_basis_best_clean.head()
# Out:
#   Subject  Freq(kHz)  Level(dB)  \
# 0  WPZ145       45.2       70.0
# 1  WPZ145       45.2       75.0
# 2  WPZ145       45.2       80.0
# 3  WPZ145        8.0       30.0
# 4  WPZ145        8.0       35.0
#
#                                            Latencies  \
# 0  [3.0751708428246016, 5.371298405466971, 6.6013...
# 1  [3.0341685649202734, 4.018223234624146, 5.9863...
# 2  [2.296127562642369, 3.6492027334851938, 6.5193...
# 3  [1.6810933940774488, 3.4031890660592254, 4.346...
# 4  [2.255125284738041, 3.1571753986332576, 4.7562...
#
#                                Transformed Waves (X)  \
# 0  [0.47124045912115675, 0.46722605388376937, 0.4...
# 1  [0.49626470635509423, 0.4848153237686717, 0.52...
# 2  [0.5232269757310333, 0.546547946100238, 0.6283...
# 3  [0.4561347254042119, 0.4896336592122058, 0.543...
# 4  [0.5750115659288366, 0.6111861911661317, 0.655...
#
#    Synapse to IHC Ratio per Freq (y2)
# 0                            9.831461
# 1                            9.831461
# 2                            9.831461
# 3                           13.977273
# 4                           13.977273

# %%
len(final_waves_df_new_basis_best_clean['Transformed Waves (X)'].iloc[0])
# Out:
# 6

# %%
X = final_waves_df_new_basis_best_clean['Transformed Waves (X)']
# X_relevant_waves = [x[:5] for x in X]
# X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_best_clean[['Freq(kHz)', 'Level(dB)']])

y = final_waves_df_new_basis_best_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
best_alpha = None
best_score = np.inf

train_rmse, test_rmse = [], []  

for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_best_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

avg_train_rmse = np.mean(train_rmse)
avg_test_rmse = np.mean(test_rmse)

avg_train_rmse, avg_test_rmse
# Out:
# (np.float64(2.8180912643222387), np.float64(2.8544033894475884))

# %%
from skfda.ml.regression import LinearRegression
from sklearn.utils import resample
import numpy as np

n_func = X_func.shape[1] 
n_bootstraps = 200
t = np.linspace(0, time_scale, 200)  # Time domain for evaluating β(t)
beta_curves = []

for i in range(n_bootstraps):
    # Bootstrap sampling
    idx = resample(np.arange(len(X_func)), replace=True)
    X_func_boot = X_func[idx]
    X_nonfunc_boot = X_nonfunc.iloc[idx].values
    y_boot = y[idx]
    X_boot_combined = np.hstack([X_func_boot, X_nonfunc_boot])
    # Fit model
    model = LinearRegression()
    model.fit(X_boot_combined, y_boot)

    # Evaluate β(t) from coeffs + basis
    phi_t = basis.evaluate(t)[:, :, 0].T
    full_coef = model.coef_[0]  # This gives you the NumPy array
    func_beta_coeffs = full_coef[:phi_t.shape[1]]  # NOW slice it

    # print("model coeff shape:",model.coef_)
    # print("phi_t shape:", phi_t.shape)
    # print("func_beta_coeffs shape:", func_beta_coeffs.shape)
    beta_t = phi_t @ func_beta_coeffs     # (200,)
    beta_curves.append(beta_t)

# %%
latencies_df = pd.DataFrame(final_waves_df_new_basis_best_clean['Latencies'])
latencies_df['Wave I Peak'] = latencies_df['Latencies'].apply(lambda x: x[0])
latencies_df['Wave II Peak'] = latencies_df['Latencies'].apply(lambda x: x[1])
latencies_df['Wave III Peak'] = latencies_df['Latencies'].apply(lambda x: x[2])
latencies_df['Wave IV Peak'] = latencies_df['Latencies'].apply(lambda x: x[3])
latencies_df['Wave V Peak'] = latencies_df['Latencies'].apply(lambda x: x[4])
waveIend = np.mean(latencies_df['Wave I Peak'])
waveIIend = np.mean(latencies_df['Wave II Peak'])
waveIIIend = np.mean(latencies_df['Wave III Peak'])
waveIVend = np.mean(latencies_df['Wave IV Peak'])
waveVsend = np.mean(latencies_df['Wave V Peak'])

latency_marks = [waveIend, waveIIend, waveIIIend, waveIVend, waveVsend]

# %%
beta_array = np.vstack(beta_curves)  # shape: (n_bootstraps, n_timepoints)
mean_beta = np.mean(beta_array, axis=0)
lower_ci = np.percentile(beta_array, 2.5, axis=0)
upper_ci = np.percentile(beta_array, 97.5, axis=0)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(t, mean_beta, label='Mean β(t)', color='blue')
plt.fill_between(t, lower_ci, upper_ci, color='blue', alpha=0.3, label='95% CI')
for x in latency_marks:
    plt.axvline(x=x, linestyle=':', color='purple', linewidth=3)

plt.ylim((-100,400))
plt.xlim((0,12))
plt.xlabel("Time (ms)")
plt.ylabel("Functional coefficient β(t)")
plt.title("Estimated Functional Coefficient with 95% Confidence Bands")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Points following wave V seem to have the highest significance? But I wouldn't code this in because ABRA did not detect a 6th peak.
#
# Larger bands = greater variability in the bootstrapping
#
# Above 0 = statistically significant [ONLY seen in 0-2.5 ms, Wave I]
#
# Bootstrapping CIs here allows for localized interpretation and doesn't assume a Gaussian distribution.
#
# OLS allows for global interpretation but it's not well tailored to a functional space.

# %%
# import statsmodels.api as sm

# X_ols = sm.add_constant(Xs)
# model = sm.OLS(y, X_ols).fit()
# print(model.summary())

# %%
# from skfda.representation.basis import BSplineBasis
# import matplotlib.pyplot as plt
# import numpy as np

# for n in range(3):
# # Assume you still have the basis used in your transformation
#     basis = bases[n]  # e.g. BSplineBasis(domain_range=(0,18), n_basis=7)
#     coeffs = Xs[n]

#     # Step 2: Evaluate basis functions at fine grid
#     t = np.linspace(*basis.domain_range[0], 200)
#     phi_t = basis.evaluate(t)[:, :, 0].T  # reshape to (200, n_basis)

#     # Step 3: Multiply basis by coefficients to reconstruct β(t)
#     # print("phi shape:", phi_t.shape, "coeffs:", coeffs.shape)
#     beta_t = phi_t @ coeffs
#     plt.plot(t, beta_t, label=f'Subject {n}')

#     # Step 4: Plot
# plt.xlabel("Time (ms)")
# plt.ylabel("β(t)")
# plt.title("Functional Coefficients β(t) Across Subjects")
# plt.grid(True)
# plt.legend()
# plt.show()

# %% [markdown]
# # 6. Adding strain as a predictor

# %%
np.unique(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Strain encoded (x5)'])
# Out:
# array([0, 1])

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []
strains = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)

        encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded\
            [(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]\
            ['Strain encoded (x5)']
        
        if len(encoded_strain_series) == 0:
            print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
            continue
        
        encoded_strain = encoded_strain_series.iloc[0]
        # print(encoded_strain)
        strains.append(encoded_strain)

        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
        smoother = BasisSmoother(basis=basis, return_basis=True)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis_strained = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strain' : strains, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
final_waves_df_new_basis_strained_clean = final_waves_df_new_basis_strained.dropna().reset_index(drop=True)

# %%
X = final_waves_df_new_basis_strained_clean['Transformed Waves (X)']
# X_relevant_waves = [x[:5] for x in X]
# X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_strained_clean[['Freq(kHz)', 'Level(dB)', 'Strain']])

y = final_waves_df_new_basis_strained_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
best_alpha = None
best_score = np.inf

train_rmse, test_rmse = [], []  

for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_strained_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

avg_train_rmse = np.mean(train_rmse)
avg_test_rmse = np.mean(test_rmse)

train_rmse = np.array(train_rmse)
test_rmse = np.array(test_rmse)

train_rmse_se = np.std(train_rmse, ddof=1) / np.sqrt(len(train_rmse))
test_rmse_se = np.std(test_rmse, ddof=1) / np.sqrt(len(test_rmse))

print(f"Train RMSE: {avg_train_rmse:.4f} ± {train_rmse_se:.4f}")
print(f"Test RMSE:  {avg_test_rmse:.4f} ± {test_rmse_se:.4f}")
# Out:
# Train RMSE: 2.7570 ± 0.0405
# Test RMSE:  2.8121 ± 0.1595

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

shared_grid = np.linspace(0, 18, 244)
penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
time_scale = 18

# tuning penalty_amount and smoother!!!!! Set up the for loop
for alpha in np.logspace(-4,2,10):
    subjects = []
    frequencies = []
    levels = []
    raw_waves = []
    newbasis_waves = []
    Xs = []
    ys = []
    fails = []
    strains = []

    for (sub, freq), df in subject_ABRs.items():
        for lvl in np.unique(df['Level(dB)']):
            latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                    & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
                ['Latencies']
            
            if len(latencies_series) == 0:
                print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
                continue

            latencies = latencies_series.values[0]
            latencies = [float(x) for x in latencies]
            # print(latencies)

            lvl = float(lvl)
            wave = full_interpolation(df, freq, lvl, time_scale)
            wave = np.asarray(wave, dtype=float)
            wave = wave.reshape(1, -1)
            
            grid = time_scale * np.arange(0, 244) / 244
            wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

            basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
            smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter=alpha)

            wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

            X = wave_newbasis.coefficients

            y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
                ['Synapse to IHC Ratio per Freq (y2)']
            
            # print(y_series)

            if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
                print(f'N/A y: ({sub}, {freq}, {lvl})')
                continue

            y = float(y_series.iloc[0])

            encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded\
            [(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]\
            ['Strain encoded (x5)']
            
            if len(encoded_strain_series) == 0:
                print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
                continue
        
            encoded_strain = encoded_strain_series.iloc[0]
            # print(encoded_strain)
            strains.append(encoded_strain)

            # print((sub, freq, lvl, y))
            subjects.append(sub)
            frequencies.append(freq)
            levels.append(lvl)
            raw_waves.append(wave_input)
            newbasis_waves.append(wave_newbasis)
            Xs.append(X.flatten()) # used for model fitting, same as for OLS!
            ys.append(y)
            
    final_waves_df_new_basis = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strains' : strains, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys})
    final_waves_df_new_basis_clean = final_waves_df_new_basis.dropna().reset_index(drop=True)

    # Start CV!!
    X = final_waves_df_new_basis_clean['Transformed Waves (X)']
    X_relevant_waves = [x for x in X]
    X_func = np.vstack([x.flatten() for x in X_relevant_waves])
    X_nonfunc = pd.DataFrame(final_waves_df_new_basis_clean[['Freq(kHz)', 'Level(dB)', 'Strains']])

    y = final_waves_df_new_basis_clean['Synapse to IHC Ratio per Freq (y2)']

    kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    best_alpha = None
    best_score = np.inf

    train_rmse, test_rmse = [], []  

    # for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
        X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
        X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        scaler = StandardScaler()
        X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
        X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

        model = LinearRegression()
        model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

        y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
        y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

        train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
        test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

    avg_train_rmse = np.mean(train_rmse)
    avg_test_rmse = np.mean(test_rmse)

    if avg_test_rmse < best_score:
        best_score = avg_test_rmse
        best_alpha = alpha

print(f"Best alpha: {best_alpha:.4e} with RMSE {best_score:.4f}")
# Out:
# Best alpha: 1.0000e+02 with RMSE 2.8173

# %%
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded.columns
# Out:
# Index(['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)',
#        'Amplitude (x3)', 'vx (x4)', 'Strain (x5)', 'Group - dB (x6)',
#        'Group - Time Elapsed', 'Group', 'Synapses to IHC (y1)', 'Synapses',
#        'IHCs', 'Group - Time Elapsed - Split', 'Group - Time Elapsed - Magn.',
#        'Group - Time Elapsed - Unit', 'Group - Hours Elapsed (x7)',
#        'Synapse to IHC Ratio per Freq (y2)', 'Strain encoded (x5)'],
#       dtype='object')

# %%
# from skfda.misc.regularization import L2Regularization
# from skfda.misc.operators import LinearDifferentialOperator

# penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
# shared_grid = np.linspace(0, time_scale, 244)
# # basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# # smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
# time_scale = 18
# subjects = []
# frequencies = []
# levels = []
# raw_waves = []
# newbasis_waves = []
# Xs = []
# ys = []
# fails = []
# strains = []
# groups = []

# for (sub, freq), df in subject_ABRs.items():
#     for lvl in np.unique(df['Level(dB)']):
#         latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
#             & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
#                 & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
#             ['Latencies']
        
#         if len(latencies_series) == 0:
#             print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
#             continue

#         latencies = latencies_series.values[0]
#         latencies = [float(x) for x in latencies]
#         # print(latencies)

#         lvl = float(lvl)
#         wave = full_interpolation(df, freq, lvl, time_scale)
#         wave = np.asarray(wave, dtype=float)
#         wave = wave.reshape(1, -1)

#         encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded\
#             [(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]\
#             ['Strain encoded (x5)']
        
#         if len(encoded_strain_series) == 0:
#             print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
#             continue

#         encoded_strain = encoded_strain_series.iloc[0]
#         # print(encoded_strain)
#         strains.append(encoded_strain)

#         group = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]['Group']
#         groups.append(group)

#         grid = time_scale * np.arange(0, 244) / 244
#         wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

#         basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)  # 1.0000e+02
#         smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter= 1.0000e+02)

#         wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

#         X = wave_newbasis.coefficients

#         y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
#             & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
#             & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
#             ['Synapse to IHC Ratio per Freq (y2)']
        
#         # print(y_series)

#         if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
#             print(f'N/A y: ({sub}, {freq}, {lvl})')
#             continue

#         y = float(y_series.iloc[0])

#         # print((sub, freq, lvl, y))
#         subjects.append(sub)
#         frequencies.append(freq)
#         levels.append(lvl)
#         raw_waves.append(wave_input)
#         newbasis_waves.append(wave_newbasis)
#         Xs.append(X.flatten()) # used for model fitting, same as for OLS!
#         ys.append(y)

# final_waves_df_new_basis_strained = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strain' : strains, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys, 'Group' : groups})
# final_waves_df_new_basis_strained_clean = final_waves_df_new_basis_strained.dropna().reset_index(drop=True)

# X = final_waves_df_new_basis_strained_clean['Transformed Waves (X)']
# # X_relevant_waves = [x[:5] for x in X]
# # X_func = np.vstack([x.flatten() for x in X_relevant_waves])
# X_func = np.vstack([x.flatten() for x in X])
# X_nonfunc = pd.DataFrame(final_waves_df_new_basis_strained_clean[['Freq(kHz)', 'Level(dB)', 'Strain']])

# y = final_waves_df_new_basis_strained_clean['Synapse to IHC Ratio per Freq (y2)']

# kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)

# train_rmse, test_rmse = [], []  
# groups = np.unique(final_waves_df_new_basis_strained_clean['Group'])

# for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_strained_clean['Subject']):
#     X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
#     X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
#     y_train, y_test = y[train_idx], y[test_idx]

#     scaler = StandardScaler()
#     X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
#     X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

#     model = LinearRegression()
#     model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

#     y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
#     y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

#     train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
#     test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

# avg_train_rmse = np.mean(train_rmse)
# avg_test_rmse = np.mean(test_rmse)

# train_rmse = np.array(train_rmse)
# test_rmse = np.array(test_rmse)

# train_rmse_se = np.std(train_rmse, ddof=1) / np.sqrt(len(train_rmse))
# test_rmse_se = np.std(test_rmse, ddof=1) / np.sqrt(len(test_rmse))

# print(f"Train RMSE: {avg_train_rmse:.4f} ± {train_rmse_se:.4f}")
# print(f"Test RMSE:  {avg_test_rmse:.4f} ± {test_rmse_se:.4f}")

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []
strains = []
groups = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)

        encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded\
            [(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]\
            ['Strain encoded (x5)']
        
        if len(encoded_strain_series) == 0:
            print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
            continue

        encoded_strain = encoded_strain_series.iloc[0]
        # print(encoded_strain)
        strains.append(encoded_strain)

        group = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)]['Group'].iloc[0]
        groups.append(group)

        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)  # 1.0000e+02
        smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter= 1.0000e+02)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Synapse to IHC Ratio per Freq (y2)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis_strained = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strain' : strains, 'Transformed Waves (X)' : Xs, 'Synapse to IHC Ratio per Freq (y2)' : ys, 'Group' : groups})
final_waves_df_new_basis_strained_clean = final_waves_df_new_basis_strained.dropna().reset_index(drop=True)

X = final_waves_df_new_basis_strained_clean['Transformed Waves (X)']
# X_relevant_waves = [x[:5] for x in X]
# X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_strained_clean[['Freq(kHz)', 'Level(dB)', 'Strain']])

y = final_waves_df_new_basis_strained_clean['Synapse to IHC Ratio per Freq (y2)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)

train_rmse, test_rmse = [], []  
groups = np.unique(final_waves_df_new_basis_strained_clean['Group'])

for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_strained_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

avg_train_rmse = np.mean(train_rmse)
avg_test_rmse = np.mean(test_rmse)

train_rmse = np.array(train_rmse)
test_rmse = np.array(test_rmse)

train_rmse_se = np.std(train_rmse, ddof=1) / np.sqrt(len(train_rmse))
test_rmse_se = np.std(test_rmse, ddof=1) / np.sqrt(len(test_rmse))

print(f"Train RMSE: {avg_train_rmse:.4f} ± {train_rmse_se:.4f}")
print(f"Test RMSE:  {avg_test_rmse:.4f} ± {test_rmse_se:.4f}\n")

from collections import defaultdict

# Initialize dictionaries to collect RMSEs for each group across folds
train_group_rmse = defaultdict(list)
test_group_rmse = defaultdict(list)

for train_idx, test_idx in kf.split(X=X_func, y=y, groups=final_waves_df_new_basis_strained_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func, X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func, X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func, X_test_nonfunc_scaled])

    # Get group labels for the train and test sets
    train_groups = final_waves_df_new_basis_strained_clean.iloc[train_idx]['Group']
    test_groups = final_waves_df_new_basis_strained_clean.iloc[test_idx]['Group']

    # Compute RMSE for each group in the train set
    for group in np.unique(train_groups):
        group_mask = (train_groups == group)
        if group_mask.sum() > 0:
            group_rmse = np.sqrt(mean_squared_error(y_train[group_mask], y_train_hat[group_mask]))
            train_group_rmse[group].append(group_rmse)

    # Compute RMSE for each group in the test set
    for group in np.unique(test_groups):
        group_mask = (test_groups == group)
        if group_mask.sum() > 0:
            group_rmse = np.sqrt(mean_squared_error(y_test[group_mask], y_test_hat[group_mask]))
            test_group_rmse[group].append(group_rmse)

# After all folds, compute the average and std RMSE per group for train and test
import pandas as pd

groups_all = sorted(set(list(train_group_rmse.keys()) + list(test_group_rmse.keys())))
results = []
for group in groups_all:
    train_rmses = train_group_rmse.get(group, [])
    test_rmses = test_group_rmse.get(group, [])
    results.append({
        'Group': group,
        'Train_RMSE_Mean': np.mean(train_rmses) if train_rmses else np.nan,
        'Train_RMSE_Std': np.std(train_rmses) if train_rmses else np.nan,
        'Test_RMSE_Mean': np.mean(test_rmses) if test_rmses else np.nan,
        'Test_RMSE_Std': np.std(test_rmses) if test_rmses else np.nan,
        'n_train': len(train_rmses),
        'n_test': len(test_rmses),
    })

results_df = pd.DataFrame(results)
# print(results_df)
# Out:
# Train RMSE: 2.7606 ± 0.0399
# Test RMSE:  2.8173 ± 0.1577
#
#              Group  Train_RMSE_Mean  Train_RMSE_Std  Test_RMSE_Mean  \
# 0   101dB 24h post         3.539226        0.182842        3.599689
# 1       14wks ctrl         2.050538        0.085729        2.103589
# 2        6wks ctrl         2.087449        0.100130        2.074880
# 3        8wks ctrl         2.045000        0.118601        2.095298
# 4     90dB 0h post         1.949816        0.173943        2.162978
# 5    90dB 24h post         2.792290        0.115605        2.688111
# 6     90dB 2w post         1.843978        0.022329        1.748013
# 7     94dB 0h post         3.042119        0.170075        2.840844
# 8    94dB 24h post         3.403467        0.181553        3.543906
# 9     94dB 2w post         3.180644        0.153133        3.188723
# 10  94dB 8wks post         1.741970        0.039391        1.808098
# 11   98dB 24h post         4.586169        0.426694        4.734745
# 12    98dB 2w post         3.930685        0.159947        4.102186
# 13  98dB 8wks post         3.183089        0.125521        3.179650
#
#     Test_RMSE_Std  n_train  n_test
# 0        0.045183        5       2
# 1        0.293167        5       5
# 2        0.196590        5       5
# 3        0.440933        5       5
# 4        0.577610        5       3
# 5        0.419073        5       3
# 6        0.476927        5       4
# 7        0.785257        5       4
# 8        0.859103        5       5
# 9        0.578772        5       3
# 10       0.226907        5       3
# 11       1.196298        5       4
# 12       0.303436        5       4
# 13       0.552082        5       5

# %%
results_df[['Group', 'Train_RMSE_Mean', 'Test_RMSE_Mean']]
# Out:
#              Group  Train_RMSE_Mean  Test_RMSE_Mean
# 0   101dB 24h post         3.539226        3.599689
# 1       14wks ctrl         2.050538        2.103589
# 2        6wks ctrl         2.087449        2.074880
# 3        8wks ctrl         2.045000        2.095298
# 4     90dB 0h post         1.949816        2.162978
# 5    90dB 24h post         2.792290        2.688111
# 6     90dB 2w post         1.843978        1.748013
# 7     94dB 0h post         3.042119        2.840844
# 8    94dB 24h post         3.403467        3.543906
# 9     94dB 2w post         3.180644        3.188723
# 10  94dB 8wks post         1.741970        1.808098
# 11   98dB 24h post         4.586169        4.734745
# 12    98dB 2w post         3.930685        4.102186
# 13  98dB 8wks post         3.183089        3.179650

# %%
# Specify the desired group order
custom_group_order = [
    '6wks ctrl',
    '8wks ctrl',
    '14wks ctrl',
    '90dB 0h post',
    '90dB 24h post',
    '90dB 2w post',
    '94dB 0h post',
    '94dB 24h post',
    '94dB 2w post',
    '94dB 8wks post',
    '98dB 24h post',
    '98dB 2w post',
    '98dB 8wks post',
    '101dB 24h post',
]

# Reindex results_df to follow the custom group order
results_df_sorted = results_df.set_index('Group').reindex(custom_group_order).reset_index()

groups = results_df_sorted['Group']
x = np.arange(len(groups))
width = 0.35

fig, ax = plt.subplots(figsize=(16, 7))

# Bar plots for Train and Test RMSE with error bars
train_means = results_df_sorted['Train_RMSE_Mean']
train_stds = results_df_sorted['Train_RMSE_Std']
test_means = results_df_sorted['Test_RMSE_Mean']
test_stds = results_df_sorted['Test_RMSE_Std']

rects1 = ax.bar(x - width/2, train_means, width, yerr=train_stds, label='Train RMSE', color='blue', alpha=0.7, capsize=5)
rects2 = ax.bar(x + width/2, test_means, width, yerr=test_stds, label='Validation RMSE', color='red', alpha=0.7, capsize=5)

ax.set_xlabel('Group')
ax.set_ylabel('RMSE')
ax.set_title('Functional Linear Model Performance by Group (Mean ± Std)')
ax.set_xticks(x)
ax.set_xticklabels(groups, rotation=45, ha='right')
ax.set_ylim((0, max(train_means.max(), test_means.max()) + 1))
ax.legend()
ax.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

train_mean_col = "Train_RMSE_Mean"
train_std_col = "Train_RMSE_Std"
val_mean_col = "Val_RMSE_Mean"
val_std_col = "Val_RMSE_Std"
test_mean_col = "Test_RMSE_Mean"
test_std_col = "Test_RMSE_Std"

labels = results_df_sorted['Group']
x = np.arange(len(labels))
width = 0.35

# Define color palette (light = train, dark = val)
color_map = {
    'ctrl_train': '#90EE90',   # Light Green
    'ctrl_val':   '#006400',   # Dark Green
    'post_train': '#ADD8E6',   # Light Blue
    'post_val':   '#00008B'    # Dark Blue
}

# Assign colors to each bar
train_colors = []
val_colors = []

for group in labels:
    if 'ctrl' in group.lower():
        train_colors.append(color_map['ctrl_train'])
        val_colors.append(color_map['ctrl_val'])
    else:
        train_colors.append(color_map['post_train'])
        val_colors.append(color_map['post_val'])

fig, ax = plt.subplots(figsize=(12, 6))

# Plot Train RMSE bars
ax.bar(
    x - width/2,
    results_df_sorted[train_mean_col],
    width,
    yerr=results_df_sorted[train_std_col],
    capsize=5,
    color=train_colors
)

# # Plot Val RMSE bars
# ax.bar(
#     x + width/2,
#     group_metrics_df_sorted[val_mean_col],
#     width,
#     yerr=group_metrics_df_sorted[val_std_col],
#     capsize=5,
#     color=val_colors
# )

# Plot Test RMSE bars
ax.bar(
    x + width/2,
    results_df_sorted[test_mean_col],
    width,
    yerr=results_df_sorted[test_std_col],
    capsize=5,
    color=val_colors
)

# Custom legend
legend_patches = [
    Patch(facecolor=color_map['ctrl_train'], label='Train RMSE (Control)'),
    Patch(facecolor=color_map['ctrl_val'], label='Test RMSE (Control)'),
    Patch(facecolor=color_map['post_train'], label='Train RMSE (Experimental)'),
    Patch(facecolor=color_map['post_val'], label='Test RMSE (Experimental)')
]

ax.legend(handles=legend_patches, loc='best')
ax.set_ylabel("RMSE")
ax.set_title("Functional Linear Model - RMSE per Experimental Group with Error Bars")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
plt.tight_layout()
plt.ylim((0,6))
plt.show()

# %% [markdown]
# # 7. Trying the same process on the original y1 data to present on

# %%
final_clean_strained_grouped_pos_cleangroup_vs_timed.columns
# Out:
# Index(['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)',
#        'Amplitude (x3)', 'vx (x4)', 'Strain (x5)', 'Group - dB (x6)',
#        'Group - Time Elapsed', 'Group', 'Synapses to IHC (y1)',
#        'Group - Time Elapsed - Split', 'Group - Time Elapsed - Magn.',
#        'Group - Time Elapsed - Unit', 'Group - Hours Elapsed (x7)'],
#       dtype='object')

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []
strains = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)

        encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded\
            [(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)]\
            ['Strain encoded (x5)']
        
        if len(encoded_strain_series) == 0:
            print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
            continue
        
        encoded_strain = encoded_strain_series.iloc[0]
        # print(encoded_strain)
        strains.append(encoded_strain)

        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
        smoother = BasisSmoother(basis=basis, return_basis=True)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Synapses to IHC (y1)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis_strained_y1 = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strain' : strains, 'Transformed Waves (X)' : Xs, 'Synapses to IHC (y1)' : ys})
final_waves_df_new_basis_strained_y1_clean = final_waves_df_new_basis_strained_y1.dropna().reset_index(drop=True)

# %%
len(final_waves_df_new_basis_strained_y1_clean)
# Out:
# 5952

# %%
X = final_waves_df_new_basis_strained_y1_clean['Transformed Waves (X)']
# X_relevant_waves = [x[:5] for x in X]
# X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_strained_y1_clean[['Freq(kHz)', 'Level(dB)']]) # , 'Strain

y = final_waves_df_new_basis_strained_y1_clean['Synapses to IHC (y1)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
best_alpha = None
best_score = np.inf

train_rmse, test_rmse = [], []  

for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_strained_y1_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

avg_train_rmse = np.mean(train_rmse)
avg_test_rmse = np.mean(test_rmse)

train_rmse = np.array(train_rmse)
test_rmse = np.array(test_rmse)

train_rmse_se = np.std(train_rmse, ddof=1) / np.sqrt(len(train_rmse))
test_rmse_se = np.std(test_rmse, ddof=1) / np.sqrt(len(test_rmse))

print(f"Train RMSE: {avg_train_rmse:.4f} ± {train_rmse_se:.4f}")
print(f"Test RMSE:  {avg_test_rmse:.4f} ± {test_rmse_se:.4f}")
# Out:
# Train RMSE: 3.3479 ± 0.0428
# Test RMSE:  3.3760 ± 0.1640

# %% [markdown]
# Finetuning

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

shared_grid = np.linspace(0, 18, 244)
penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
time_scale = 18

# tuning penalty_amount and smoother!!!!! Set up the for loop
for alpha in np.logspace(-4,2,10):
    subjects = []
    frequencies = []
    levels = []
    raw_waves = []
    newbasis_waves = []
    Xs = []
    ys = []
    fails = []
    strains = []

    for (sub, freq), df in subject_ABRs.items():
        for lvl in np.unique(df['Level(dB)']):
            latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                    & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
                ['Latencies']
            
            if len(latencies_series) == 0:
                print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
                continue

            latencies = latencies_series.values[0]
            latencies = [float(x) for x in latencies]
            # print(latencies)

            lvl = float(lvl)
            wave = full_interpolation(df, freq, lvl, time_scale)
            wave = np.asarray(wave, dtype=float)
            wave = wave.reshape(1, -1)
            
            grid = time_scale * np.arange(0, 244) / 244
            wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

            basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
            smoother = BasisSmoother(basis=basis, return_basis=True, regularization=penalty, smoothing_parameter=alpha)

            wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

            X = wave_newbasis.coefficients

            y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
                ['Synapses to IHC (y1)']
            
            # print(y_series)

            if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
                print(f'N/A y: ({sub}, {freq}, {lvl})')
                continue
            
            # print(len(y_series))
            for n in range(len(y_series)):
                y = float(y_series.iloc[n])

            # print((sub, freq, lvl, y))
                subjects.append(sub)
                frequencies.append(freq)
                levels.append(lvl)
                raw_waves.append(wave_input)
                newbasis_waves.append(wave_newbasis)
                Xs.append(X.flatten()) # used for model fitting, same as for OLS!
                ys.append(y)
            
    final_waves_df_new_basis_y1 = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Transformed Waves (X)' : Xs, 'Synapses to IHC (y1)' : ys})
    final_waves_df_new_basis_clean_y1 = final_waves_df_new_basis_y1.dropna().reset_index(drop=True)

    # Start CV!!
    X = final_waves_df_new_basis_clean_y1['Transformed Waves (X)']
    X_relevant_waves = [x for x in X]
    X_func = np.vstack([x.flatten() for x in X_relevant_waves])
    X_nonfunc = pd.DataFrame(final_waves_df_new_basis_clean_y1[['Freq(kHz)', 'Level(dB)', 'Strain ']])

    y = final_waves_df_new_basis_clean_y1['Synapses to IHC (y1)']

    kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
    best_alpha = None
    best_score = np.inf

    train_rmse, test_rmse = [], []  

    # for train_idx, test_idx in kf.split(X=X_nonfunc ,y=y,groups=final_waves_df_new_basis_clean['Subject']):
    for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_clean_y1['Subject']):
        X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
        X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        scaler = StandardScaler()
        X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
        X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

        model = LinearRegression()
        model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

        y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
        y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

        train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
        test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

    avg_train_rmse = np.mean(train_rmse)
    avg_test_rmse = np.mean(test_rmse)

    if avg_test_rmse < best_score:
        best_score = avg_test_rmse
        best_alpha = alpha

print(f"Best alpha: {best_alpha:.4e} with RMSE {best_score:.4f}")
# Out:
# Best alpha: 1.0000e+02 with RMSE 3.3637

# %%
len(final_waves_df_new_basis_clean_y1)
# Out:
# 12308

# %%
final_waves_df_new_basis_clean_y1.columns
# Out:
# Index(['Subject', 'Freq(kHz)', 'Level(dB)', 'Transformed Waves (X)',
#        'Synapses to IHC (y1)'],
#       dtype='object')

# %%
final_waves_df_new_basis_strained_y1_clean['Synapses to IHC (y1)'].describe()
# Out:
# count    5952.000000
# mean       15.027080
# std         3.457474
# min         0.000000
# 25%        13.958333
# 50%        15.918367
# 75%        17.282609
# max        20.322581
# Name: Synapses to IHC (y1), dtype: float64

# %%
final_waves_df_new_basis_strained_clean['Synapse to IHC Ratio per Freq (y2)'].describe()
# Out:
# count    5952.000000
# mean       15.202411
# std         2.948817
# min         1.366120
# 25%        14.318182
# 50%        15.925926
# 75%        17.276596
# max        20.107527
# Name: Synapse to IHC Ratio per Freq (y2), dtype: float64

# %% [markdown]
# ## Testing on only v1

# %%
from skfda.misc.regularization import L2Regularization
from skfda.misc.operators import LinearDifferentialOperator

penalty = L2Regularization(linear_operator=LinearDifferentialOperator(2))
shared_grid = np.linspace(0, time_scale, 244)
# basis = BSplineBasis(n_basis=7, domain_range=(0,18)) # old
# smoother = BasisSmoother(basis=basis, return_basis=True) # , regularization=penalty, smoothing_parameter=0.1, 
time_scale = 18
subjects = []
frequencies = []
levels = []
raw_waves = []
newbasis_waves = []
Xs = []
ys = []
fails = []
strains = []

for (sub, freq), df in subject_ABRs.items():
    for lvl in np.unique(df['Level(dB)']):
        latencies_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
                & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)]\
            ['Latencies']
        
        if len(latencies_series) == 0:
            print(f'N/A latencies: ({sub}, {freq}, {lvl}) : {latencies_series}')
            continue

        latencies = latencies_series.values[0]
        latencies = [float(x) for x in latencies]
        # print(latencies)

        lvl = float(lvl)
        wave = full_interpolation(df, freq, lvl, time_scale)
        wave = np.asarray(wave, dtype=float)
        wave = wave.reshape(1, -1)

        encoded_strain_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded\
            [(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)]\
            ['Strain encoded (x5)']
        
        if len(encoded_strain_series) == 0:
            print(f'No strain found: ({sub}, {freq}, {lvl}) : {encoded_strain_series}')
            continue
        
        encoded_strain = encoded_strain_series.iloc[0]
        # print(encoded_strain)
        strains.append(encoded_strain)

        grid = time_scale * np.arange(0, 244) / 244
        wave_input = skfda.FDataGrid(data_matrix=wave,grid_points=shared_grid)

        basis = BSplineBasis(domain_range=(latencies[0], latencies[-1]),knots = latencies, order = 3)
        smoother = BasisSmoother(basis=basis, return_basis=True)

        wave_newbasis = smoother.fit_transform(wave_input)[0] # smoother will allow regularization for further tuning down the line...

        X = wave_newbasis.coefficients

        y_series = final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded[(final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Subject'] == sub)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Freq(kHz) (x1)'] == freq)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['Level(dB) (x2)'] == lvl)\
            & (final_clean_strained_grouped_pos_cleangroup_vs_timed_avgvx_encoded['vx (x4)'] == 'v1')]\
            ['Synapses to IHC (y1)']
        
        # print(y_series)

        if len(y_series) == 0 or pd.isna(y_series.iloc[0]):
            print(f'N/A y: ({sub}, {freq}, {lvl})')
            continue

        y = float(y_series.iloc[0])

        # print((sub, freq, lvl, y))
        subjects.append(sub)
        frequencies.append(freq)
        levels.append(lvl)
        raw_waves.append(wave_input)
        newbasis_waves.append(wave_newbasis)
        Xs.append(X.flatten()) # used for model fitting, same as for OLS!
        ys.append(y)

final_waves_df_new_basis_strained_y1_x1only = pd.DataFrame(data = {'Subject' : subjects, 'Freq(kHz)' : frequencies, 'Level(dB)' : levels, 'Strain' : strains, 'Transformed Waves (X)' : Xs, 'Synapses to IHC (y1)' : ys})
final_waves_df_new_basis_strained_y1_x1only_clean = final_waves_df_new_basis_strained_y1_x1only.dropna().reset_index(drop=True)

# %%
X = final_waves_df_new_basis_strained_y1_x1only_clean['Transformed Waves (X)']
# X_relevant_waves = [x[:5] for x in X]
# X_func = np.vstack([x.flatten() for x in X_relevant_waves])
X_func = np.vstack([x.flatten() for x in X])
X_nonfunc = pd.DataFrame(final_waves_df_new_basis_strained_y1_x1only_clean[['Freq(kHz)', 'Level(dB)', 'Strain']]) # , 'Strain

y = final_waves_df_new_basis_strained_y1_x1only_clean['Synapses to IHC (y1)']

kf = GroupKFold(n_splits=5, shuffle=True, random_state=42)
best_alpha = None
best_score = np.inf

train_rmse, test_rmse = [], []  

for train_idx, test_idx in kf.split(X=X_func ,y=y,groups=final_waves_df_new_basis_strained_y1_x1only_clean['Subject']):
    X_train_func, X_test_func = X_func[train_idx], X_func[test_idx]
    X_train_nonfunc, X_test_nonfunc = X_nonfunc.iloc[train_idx], X_nonfunc.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    scaler = StandardScaler()
    X_train_nonfunc_scaled = scaler.fit_transform(X_train_nonfunc)
    X_test_nonfunc_scaled = scaler.transform(X_test_nonfunc)

    model = LinearRegression()
    model.fit([X_train_func,X_train_nonfunc_scaled], y_train)

    y_train_hat = model.predict([X_train_func,X_train_nonfunc_scaled])
    y_test_hat = model.predict([X_test_func,X_test_nonfunc_scaled])

    train_rmse.append(np.sqrt(mean_squared_error(y_train, y_train_hat)))
    test_rmse.append(np.sqrt(mean_squared_error(y_test, y_test_hat)))

avg_train_rmse = np.mean(train_rmse)
avg_test_rmse = np.mean(test_rmse)

train_rmse = np.array(train_rmse)
test_rmse = np.array(test_rmse)

train_rmse_se = np.std(train_rmse, ddof=1) / np.sqrt(len(train_rmse))
test_rmse_se = np.std(test_rmse, ddof=1) / np.sqrt(len(test_rmse))

print(f"Train RMSE: {avg_train_rmse:.4f} ± {train_rmse_se:.4f}")
print(f"Test RMSE:  {avg_test_rmse:.4f} ± {test_rmse_se:.4f}")
# Out:
# Train RMSE: 3.3145 ± 0.0488
# Test RMSE:  3.3644 ± 0.1806

# %% [markdown]
# # 8. Interaction Terms

# %% [markdown]
# To increase interpretability, better to test these in a linear model and then inject into GAT

# %%
final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded.columns
# Out:
# Index(['Subject', 'Latencies', 'Freq(kHz) (x1)', 'Level(dB) (x2)',
#        'Amplitude (x3)', 'vx (x4)', 'Strain (x5)', 'Group - dB (x6)',
#        'Group - Time Elapsed', 'Group', 'Synapses to IHC (y1)', 'Synapses',
#        'IHCs', 'Group - Time Elapsed - Split', 'Group - Time Elapsed - Magn.',
#        'Group - Time Elapsed - Unit', 'Group - Hours Elapsed (x7)',
#        'Synapse to IHC Ratio per Freq (y2)', 'Strain encoded (x5)'],
#       dtype='object')

# %%
# X_func_array = np.vstack(X_func)
# flm_df = pd.DataFrame(X_func_array, columns=[f'Wave{i+1}' for i in range(X_func_array.shape[1])])

# scalar_df = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded[['Freq(kHz) (x1)', 'Level(dB) (x2)', 'Strain encoded (x5)']]
# scalar_df = scalar_df.rename(columns={'Freq(kHz) (x1)' : 'Freq', 'Level(dB) (x2)' : 'Level', 'Strain encoded (x5)' : 'Strain'})

# df = pd.concat([scalar_df.reset_index(drop=True), flm_df], axis=1)
# df['y'] = final_clean_strained_grouped_pos_cleangroup_vs_timed2_avgvx_encoded['Synapse to IHC Ratio per Freq (y2)'].reset_index(drop=True)

# all_features = scalar_df.columns.tolist() + flm_df.columns.tolist()
# formula = 'y ~ (' + ' + '.join(all_features) + ') ** 2'

# import statsmodels.formula.api as smf

# model = smf.ols(formula=formula, data=df).fit()
# print(model.summary())

# %% [markdown]
# OLS will not work, too easily swayed by MC which is rampant in FLMs. Will continue using bootstrapping to assess interactive significance.

# %% [markdown]
# # 8. Dividing Wave I into parts (check with Peeyush!!!)
